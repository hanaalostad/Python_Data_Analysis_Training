# %% [markdown]
# ### Data Visualization
#
# **Choosing the Right Chart**
#
# ![image.png](attachment:image.png)

# %%
pip install matplotlib seaborn folium branca Geopandas plotly
# Out:
# Requirement already satisfied: matplotlib in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (3.8.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: seaborn in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: folium in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (0.19.4)
# Requirement already satisfied: branca in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (0.8.1)
# Requirement already satisfied: Geopandas in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (1.0.1)
# Requirement already satisfied: plotly in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (5.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: jinja2>=2.9 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from folium) (2025.1.0)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from Geopandas) (0.10.0)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from Geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from Geopandas) (2.0.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2022.2.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: certifi in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from pyogrio>=0.7.2->Geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from requests->folium) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\halos\appdata\local\programs\python\python310\lib\site-packages (from requests->folium) (1.26.20)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap
import geopandas as gpd

# %% [markdown]
# **Line Chart (For Trends Over Time)**
#
# Showing changes over time (e.g., sales trends, stock prices).
#
# Tracking continuous data like temperature, revenue, or population growth.

# %%
# Sample data
years = [2019, 2020, 2021, 2022, 2023]
sales = [10000, 15000, 20000, 25000, 30000]

# Line plot
plt.plot(years, sales, marker="o", linestyle="-", color="blue")
plt.title("Annual Sales Growth")
plt.xlabel("Year")
plt.ylabel("Sales ($)")
plt.show()

# %% [markdown]
# **Bar Chart (For Comparing Categories)**
#
#
# Comparing different categories (e.g., sales by product, revenue by city).
#
# Displaying counts or sums across groups.

# %%
# Sample data
categories = ["Laptop", "Phone", "Tablet", "Monitor"]
sales = [5000, 7000, 8000, 6000]

# Bar plot
sns.barplot(x=categories, y=sales)
plt.title("Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales ($)")
plt.show()

# %% [markdown]
# **Histogram (For Data Distribution)**
#
# Understanding the distribution of numerical data (e.g., salary distribution).
#
# Identifying skewness and outliers.

# %%
Employees = pd.read_csv("Employees.csv")
print(Employees)
# Out:
#    EmployeeID     Name  Age Department  Salary           City
# 0         101    Alice   25         HR   50000       New York
# 1         102      Bob   30         IT   60000        Chicago
# 2         103  Charlie   35    Finance   70000        Houston
# 3         104    David   40  Marketing   80000          Miami
# 4         105      Eve   28         IT   62000    Los Angeles
# 5         106    Frank   45    Finance   75000  San Francisco
# 6         107    Grace   50         HR   55000       New York
# 7         108     Hank   29  Marketing   58000         Boston
# 8         109      Ivy   32         IT   67000        Seattle
# 9         110     Jack   37    Finance   72000        Chicago

# %%
# Histogram for Salary Distribution
sns.histplot(Employees["Salary"], bins=4)
plt.title("Salary Distribution")
plt.show()

# %% [markdown]
# **Boxplot (For Outlier Detection & Summary Stats)**
#
# Identifying outliers and data spread.
#
# Comparing multiple distributions (e.g., salary differences across departments).

# %%
# Boxplot for Salary Data
Salary_outliers = pd.read_csv("salary_outliers.csv")
sns.boxplot(x=Salary_outliers["Salary"])
plt.title("Salary Boxplot")
plt.show()

# %%
# Load dataset
df = pd.read_csv("f1_scores.csv")

# Create Boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="Model", y="F1_Score")

# Title and labels
plt.title("Comparison of Machine Learning Models F1-Scores")
plt.xlabel("Machine Learning Model")
plt.ylabel("F1 Score")
plt.show()

# %% [markdown]
# **Pie Chart (For Proportions & Percentages)**
#
# Showing proportions of a whole (e.g., market share, department sizes).
#
# Data adds up to 100%.

# %%
# Sample data
labels = ["HR", "IT", "Finance", "Marketing"]
sizes = [10, 30, 25, 35]

# Pie chart
plt.pie(sizes, labels=labels, autopct="%1.1f%%")
plt.title("Employee Distribution by Department")
plt.show()

# %% [markdown]
# **Scatter Plot (For Relationships & Correlation)**
#
# Checking correlation between two numerical variables (e.g., age vs. salary).
#
# Identifying clusters or trends in data.

# %%
# Scatter plot for Age vs Salary
sns.scatterplot(x=Employees["Age"], y=Employees["Salary"], color="green")
plt.title("Age vs Salary")
plt.show()

# %% [markdown]
# **Heatmap (For Relationships Between Multiple Variables)**
#
# Visualizing correlation matrices.
#
# Finding patterns in large datasets.

# %%
# Heatmap of correlations
sns.heatmap(Employees[["Salary","Age"]].corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# **Bar Chart (Category Counts/Sum/Averages)**

# %%
# Bar Chart example average Salary per department 
 
Employees.groupby("Department")["Salary"].mean().plot(kind="bar", title="Average Salary per Department")
plt.xlabel("Department")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# **Histogram (Distribution of Data)**

# %%
# Histogram
sns.histplot(Employees["Age"], bins=4)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution")
plt.show()

# %%
sns.lineplot(x=Employees["EmployeeID"], y=Employees["Salary"], marker="o", color="red")
plt.title("Salary Trend")
plt.show()

# %% [markdown]
# ### Activity

# %%
# use the sales_data dataframe
sales_data = pd.read_csv("sales_data.csv")
sales_data
# Out:
#    OrderID        Date     Customer  Product  Quantity   Price   Total  \
# 0     1001  2024-01-01     John Doe   Laptop         1  1000.0     NaN
# 1     1002  2024-01-02  Alice Smith    Phone         2   500.0  1000.0
# 2     1003  2024-01-03          NaN   Tablet         1   300.0   300.0
# 3     1004  2024-01-04  Charlie Lee  Monitor         2     NaN   400.0
# 4     1005         NaN    Eve Davis   Laptop         1  1000.0  1000.0
# 5     1006  2024-01-06          NaN   Tablet         3   300.0   900.0
#
#             City
# 0       New York
# 1  San Francisco
# 2    Los Angeles
# 3         Boston
# 4        Chicago
# 5          Miami

# %% [markdown]
# **Create a heatmap for sales_data to check correlations between Price, Quantity, and TotalAmount.**

# %%
df_corr = sales_data[["Price", "Quantity", "Total"]].corr()

sns.heatmap(df_corr, annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# **Create a scatter plot to check the relationship between Price and Quantity.**

# %%
sns.scatterplot(x=sales_data["Price"], y=sales_data["Quantity"], color="green")
plt.title("Price vs. Quantity Sold")
plt.xlabel("Price ($)")
plt.ylabel("Quantity")
plt.show()

# %% [markdown]
# ### Geomaps charts

# %%
# Create a Kuwait map
kuwait_map = folium.Map(location=[29.3759, 47.9774], zoom_start=9)

# Define major city locations
kuwait_cities = {
    "Kuwait City": [29.3759, 47.9774],
    "Hawalli": [29.3322, 48.0282],
    "Salmiya": [29.3375, 48.0764],
    "Al Jahra": [29.3375, 47.6581],
    "Fahaheel": [29.0961, 48.1301]
}

# Add markers for each city
for city, coordinates in kuwait_cities.items():
    folium.Marker(
        location=coordinates,
        popup=city,
        tooltip=f"Click for {city}"
    ).add_to(kuwait_map)

# Display map
kuwait_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b382054c264a5259aff461afedbeba5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b382054c264a5259aff461afedbeba5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b382054c264a5259aff461afedbeba5b = L.map(
#                 &quot;map_b382054c264a5259aff461afedbeba5b&quot;,
#                 {
#                     center: [29.3759, 47.9774],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44c50faec713546515c3795dcff4f393 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_44c50faec713546515c3795dcff4f393.addTo(map_b382054c264a5259aff461afedbeba5b);
#
#
#             var marker_815817abc92a6ab543cea14b8e62eb0a = L.marker(
#                 [29.3759, 47.9774],
#                 {
# }
#             ).addTo(map_b382054c264a5259aff461afedbeba5b);
#
#
#         var popup_8aa38d8df9acff872099aa3bce486ba1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63376448fb8323c8bd0183380d062d2d = $(`&lt;div id=&quot;html_63376448fb8323c8bd0183380d062d2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kuwait City&lt;/div&gt;`)[0];
#                 popup_8aa38d8df9acff872099aa3bce486ba1.setContent(html_63376448fb8323c8bd0183380d062d2d);
#
#
#
#         marker_815817abc92a6ab543cea14b8e62eb0a.bindPopup(popup_8aa38d8df9acff872099aa3bce486ba1)
#         ;
#
#
#
#
#             marker_815817abc92a6ab543cea14b8e62eb0a.bindTooltip(
#                 `&lt;div&gt;
#                      Click for Kuwait City
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_e0d15499e1c47bd9336092f20820b4a4 = L.marker(
#                 [29.3322, 48.0282],
#                 {
# }
#             ).addTo(map_b382054c264a5259aff461afedbeba5b);
#
#
#         var popup_d8c928ece439ea9c79b6f7a2539b7a5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_251b2fc42040fec734d7306104af5ef5 = $(`&lt;div id=&quot;html_251b2fc42040fec734d7306104af5ef5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hawalli&lt;/div&gt;`)[0];
#                 popup_d8c928ece439ea9c79b6f7a2539b7a5a.setContent(html_251b2fc42040fec734d7306104af5ef5);
#
#
#
#         marker_e0d15499e1c47bd9336092f20820b4a4.bindPopup(popup_d8c928ece439ea9c79b6f7a2539b7a5a)
#         ;
#
#
#
#
#             marker_e0d15499e1c47bd9336092f20820b4a4.bindTooltip(
#                 `&lt;div&gt;
#                      Click for Hawalli
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_56d52746387a4bd9b57490f973bf9053 = L.marker(
#                 [29.3375, 48.0764],
#                 {
# }
#             ).addTo(map_b382054c264a5259aff461afedbeba5b);
#
#
#         var popup_8f414258d82acb1d777c36c564686be2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_614838c6a649317b4f445f811a392794 = $(`&lt;div id=&quot;html_614838c6a649317b4f445f811a392794&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Salmiya&lt;/div&gt;`)[0];
#                 popup_8f414258d82acb1d777c36c564686be2.setContent(html_614838c6a649317b4f445f811a392794);
#
#
#
#         marker_56d52746387a4bd9b57490f973bf9053.bindPopup(popup_8f414258d82acb1d777c36c564686be2)
#         ;
#
#
#
#
#             marker_56d52746387a4bd9b57490f973bf9053.bindTooltip(
#                 `&lt;div&gt;
#                      Click for Salmiya
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_50de3986472b9a15bf79d75a79147ae7 = L.marker(
#                 [29.3375, 47.6581],
#                 {
# }
#             ).addTo(map_b382054c264a5259aff461afedbeba5b);
#
#
#         var popup_900ebf663de3303676975170fe52dc77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5039333851dec3d196451378fa5129e = $(`&lt;div id=&quot;html_b5039333851dec3d196451378fa5129e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Al Jahra&lt;/div&gt;`)[0];
#                 popup_900ebf663de3303676975170fe52dc77.setContent(html_b5039333851dec3d196451378fa5129e);
#
#
#
#         marker_50de3986472b9a15bf79d75a79147ae7.bindPopup(popup_900ebf663de3303676975170fe52dc77)
#         ;
#
#
#
#
#             marker_50de3986472b9a15bf79d75a79147ae7.bindTooltip(
#                 `&lt;div&gt;
#                      Click for Al Jahra
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );

# %%
# Sample sales data for Kuwait
kuwait_sales_data = pd.DataFrame({
    "Store": ["Store A", "Store B", "Store C", "Store D", "Store E"],
    "Latitude": [29.3759, 29.3322, 29.3375, 29.3375, 29.0961],
    "Longitude": [47.9774, 48.0282, 48.0764, 47.6581, 48.1301],
    "Sales": [50000, 70000, 90000, 60000, 75000]
})

# Create a Kuwait sales map
kuwait_sales_map = folium.Map(location=[29.3759, 47.9774], zoom_start=9)

# Add sales markers
for index, row in kuwait_sales_data.iterrows():
    folium.Marker(
        location=[row["Latitude"], row["Longitude"]],
        popup=f"{row['Store']} Sales: KD {row['Sales']}",
        tooltip=row["Store"],
        icon=folium.Icon(icon="cloud"),
    ).add_to(kuwait_sales_map)

# Display map
kuwait_sales_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c43f2d17ff68d3299bd93964000a1a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c43f2d17ff68d3299bd93964000a1a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c43f2d17ff68d3299bd93964000a1a0 = L.map(
#                 &quot;map_3c43f2d17ff68d3299bd93964000a1a0&quot;,
#                 {
#                     center: [29.3759, 47.9774],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0e25758678966a3979a469b0b4f0820 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c0e25758678966a3979a469b0b4f0820.addTo(map_3c43f2d17ff68d3299bd93964000a1a0);
#
#
#             var marker_fadebc28a590d0cd26acc47382df5bb4 = L.marker(
#                 [29.3759, 47.9774],
#                 {
# }
#             ).addTo(map_3c43f2d17ff68d3299bd93964000a1a0);
#
#
#             var icon_9f07e4dcdef8c39fc9f25540faa8024c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_fadebc28a590d0cd26acc47382df5bb4.setIcon(icon_9f07e4dcdef8c39fc9f25540faa8024c);
#
#
#         var popup_7fbc33fadd6c83eeb466e47a6b1a4bb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f42ebf807232fb5bf3698604bc85e25 = $(`&lt;div id=&quot;html_9f42ebf807232fb5bf3698604bc85e25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Store A Sales: KD 50000&lt;/div&gt;`)[0];
#                 popup_7fbc33fadd6c83eeb466e47a6b1a4bb7.setContent(html_9f42ebf807232fb5bf3698604bc85e25);
#
#
#
#         marker_fadebc28a590d0cd26acc47382df5bb4.bindPopup(popup_7fbc33fadd6c83eeb466e47a6b1a4bb7)
#         ;
#
#
#
#
#             marker_fadebc28a590d0cd26acc47382df5bb4.bindTooltip(
#                 `&lt;div&gt;
#                      Store A
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_01cc9db4cb2798d67683e3c99f139869 = L.marker(
#                 [29.3322, 48.0282],
#                 {
# }
#             ).addTo(map_3c43f2d17ff68d3299bd93964000a1a0);
#
#
#             var icon_ec799fba00eecc4a61502888044035ae = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_01cc9db4cb2798d67683e3c99f139869.setIcon(icon_ec799fba00eecc4a61502888044035ae);
#
#
#         var popup_0d199144b847d24df4bc754c3ff7fed9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_976788e67637847edfa077d656d9f353 = $(`&lt;div id=&quot;html_976788e67637847edfa077d656d9f353&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Store B Sales: KD 70000&lt;/div&gt;`)[0];
#                 popup_0d199144b847d24df4bc754c3ff7fed9.setContent(html_976788e67637847edfa077d656d9f353);
#
#
#
#         marker_01cc9db4cb2798d67683e3c99f139869.bindPopup(popup_0d199144b847d24df4bc754c3ff7fed9)
#         ;
#
#
#
#
#             marker_01cc9db4cb2798d67683e3c99f139869.bindTooltip(
#                 `&lt;div&gt;
#                      Store B
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_93cc39d2d8894aa542a93819731c1b37 = L.marker(
#                 [29.3375, 48.0764],
#                 {
# }
#             ).addTo(map_3c43f2d17ff68d3299bd93964000a1a0);
#
#
#             var icon_bca3e1cfd5d3a8c5bcfb47147ea351f9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_93cc39d2d8894aa542a93819731c1b37.setIcon(icon_bca3e1cfd5d3a8c5bcfb47147ea351f9);
#
#
#         var popup_a49320d53c87171ccc373dfd7b8abb82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3449aaad8de53b6611e4536c2659ae43 = $(`&lt;div id=&quot;html_3449aaad8de53b6611e4536c2659ae43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Store C Sales: KD 90000&lt;/div&gt;`)[0];
#                 popup_a49320d53c87171ccc373dfd7b8abb82.setContent(html_3449aaad8de53b6611e4536c2659ae43);

# %%
# Create Kuwait heatmap
kuwait_heatmap = folium.Map(location=[29.3759, 47.9774], zoom_start=9)

# Convert sales data into a list format
heat_data = kuwait_sales_data[["Latitude", "Longitude", "Sales"]].values.tolist()

# Add HeatMap
HeatMap(heat_data).add_to(kuwait_heatmap)

# Display heatmap
kuwait_heatmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da592d64efc83aa31bb18cee92745e57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da592d64efc83aa31bb18cee92745e57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da592d64efc83aa31bb18cee92745e57 = L.map(
#                 &quot;map_da592d64efc83aa31bb18cee92745e57&quot;,
#                 {
#                     center: [29.3759, 47.9774],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_473b8d448eb72800da89d90fb99f10bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_473b8d448eb72800da89d90fb99f10bd.addTo(map_da592d64efc83aa31bb18cee92745e57);
#
#
#             var heat_map_774661924ea4263bd27246f5beb88b87 = L.heatLayer(
#                 [[29.3759, 47.9774, 50000.0], [29.3322, 48.0282, 70000.0], [29.3375, 48.0764, 90000.0], [29.3375, 47.6581, 60000.0], [29.0961, 48.1301, 75000.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_774661924ea4263bd27246f5beb88b87.addTo(map_da592d64efc83aa31bb18cee92745e57);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json
# Load Kuwait geoJSON file
with open("kuwait.geojson", "r") as f:
    kuwait_geojson = json.load(f)

# Create a map
kuwait_map = folium.Map(location=[29.3759, 47.9774], zoom_start=8)

# Add choropleth (color shading based on Population)
folium.Choropleth(
    geo_data=kuwait_geojson,
    name="Population",
    data={f["properties"]["Governorate"]: f["properties"]["Population"] for f in kuwait_geojson["features"]},
    key_on="feature.properties.Governorate",
    fill_color="Blues",
    fill_opacity=0.7,
    line_opacity=0.5,
    show=False,
    legend_name="Population per Governorate"
).add_to(kuwait_map)

folium.LayerControl(collapsed=False).add_to(kuwait_map)

# Show map
kuwait_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbda4efc16a73bf0dee34871da769785 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbda4efc16a73bf0dee34871da769785&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbda4efc16a73bf0dee34871da769785 = L.map(
#                 &quot;map_fbda4efc16a73bf0dee34871da769785&quot;,
#                 {
#                     center: [29.3759, 47.9774],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db82318f50f08de3f17f660bf84f531a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db82318f50f08de3f17f660bf84f531a.addTo(map_fbda4efc16a73bf0dee34871da769785);
#
#
#             var choropleth_84cd7aa20b8cbf34eed5d4a477986a27 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_ee3a705584f561d463ebd83c8cfa1c27_styler(feature) {
#             switch(feature.properties.Governorate) {
#                 case &quot;Capital&quot;: case &quot;Jahra&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Hawalli&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3182bd&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 case &quot;Farwaniya&quot;: case &quot;Ahmadi&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ee3a705584f561d463ebd83c8cfa1c27_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ee3a705584f561d463ebd83c8cfa1c27 = L.geoJson(null, {
#                 onEachFeature: geo_json_ee3a705584f561d463ebd83c8cfa1c27_onEachFeature,
#
#                 style: geo_json_ee3a705584f561d463ebd83c8cfa1c27_styler,
#             ...{
# }
#         });
#
#         function geo_json_ee3a705584f561d463ebd83c8cfa1c27_add (data) {
#             geo_json_ee3a705584f561d463ebd83c8cfa1c27
#                 .addData(data);
#         }
#             geo_json_ee3a705584f561d463ebd83c8cfa1c27_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[47.9484, 29.3894], [48.0321, 29.3894], [48.0321, 29.4422], [47.9484, 29.4422], [47.9484, 29.3894]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;Governorate&quot;: &quot;Capital&quot;, &quot;Population&quot;: 610125}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[48.0032, 29.2954], [48.0832, 29.2954], [48.0832, 29.3554], [48.0032, 29.3554], [48.0032, 29.2954]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;Governorate&quot;: &quot;Hawalli&quot;, &quot;Population&quot;: 1018865}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[47.9132, 29.2621], [47.9981, 29.2621], [47.9981, 29.3221], [47.9132, 29.3221], [47.9132, 29.2621]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;Governorate&quot;: &quot;Farwaniya&quot;, &quot;Population&quot;: 1259442}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[48.1121, 28.9953], [48.1852, 28.9953], [48.1852, 29.1204], [48.1121, 29.1204], [48.1121, 28.9953]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;Governorate&quot;: &quot;Ahmadi&quot;, &quot;Population&quot;: 1122387}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[47.6101, 29.3391], [47.7384, 29.3391], [47.7384, 29.3891], [47.6101, 29.3891], [47.6101, 29.3391]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;Governorate&quot;: &quot;Jahra&quot;, &quot;Population&quot;: 637247}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[48.0512, 29.1561], [48.1112, 29.1561], [48.1112, 29.2161], [48.0512, 29.2161], [48.0512, 29.1561]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;Governorate&quot;: &quot;Mubarak Al-Kabeer&quot;, &quot;Population&quot;: 263000}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});

# %%
import plotly.express as px
import pandas as pd

# Sample sales data for Kuwait
kuwait_sales_data = pd.DataFrame({
    "Store": ["Store A", "Store B", "Store C", "Store D", "Store E"],
    "Latitude": [29.3759, 29.3322, 29.3375, 29.3375, 29.0961],
    "Longitude": [47.9774, 48.0282, 48.0764, 47.6581, 48.1301],
    "Sales": [50000, 70000, 90000, 60000, 75000]
})

# Create scatter map using Plotly
fig = px.scatter_mapbox(
    kuwait_sales_data,
    lat="Latitude",
    lon="Longitude",
    text="Store",
    size="Sales",
    color="Sales",
    color_continuous_scale="Blues",
    mapbox_style="open-street-map",
    zoom=9,
    title="Kuwait Sales Locations"
)

# Show map
fig.show()
